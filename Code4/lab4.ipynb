# %%
import pandas as pd

# %%
df=pd.read_json('/Users/parikhandelwal/Downloads/train.json',encoding='unicode_escape')

# %%
df
# Out:
#           id      cuisine                                        ingredients
# 0      10259        greek  [romaine lettuce, black olives, grape tomatoes...
# 1      25693  southern_us  [plain flour, ground pepper, salt, tomatoes, g...
# 2      20130     filipino  [eggs, pepper, salt, mayonaise, cooking oil, g...
# 3      22213       indian                [water, vegetable oil, wheat, salt]
# 4      13162       indian  [black pepper, shallots, cornflour, cayenne pe...
# ...      ...          ...                                                ...
# 39769  29109        irish  [light brown sugar, granulated sugar, butter, ...
# 39770  11462      italian  [KRAFT Zesty Italian Dressing, purple onion, b...
# 39771   2238        irish  [eggs, citrus fruit, raisins, sourdough starte...
# 39772  41882      chinese  [boneless chicken skinless thigh, minced garli...
# 39773   2362      mexican  [green chile, jalapeno chilies, onions, ground...
#
# [39774 rows x 3 columns]

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 39774 entries, 0 to 39773
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           39774 non-null  int64
#  1   cuisine      39774 non-null  str
#  2   ingredients  39774 non-null  object
# dtypes: int64(1), object(1), str(1)
# memory usage: 932.3+ KB

# %%
df.shape
# Out:
# (39774, 3)

# %%
df.isnull().sum()
# Out:
# id             0
# cuisine        0
# ingredients    0
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# np.int64(0)

# %%
df.head()
# Out:
#       id      cuisine                                        ingredients
# 0  10259        greek  [romaine lettuce, black olives, grape tomatoes...
# 1  25693  southern_us  [plain flour, ground pepper, salt, tomatoes, g...
# 2  20130     filipino  [eggs, pepper, salt, mayonaise, cooking oil, g...
# 3  22213       indian                [water, vegetable oil, wheat, salt]
# 4  13162       indian  [black pepper, shallots, cornflour, cayenne pe...

# %%
df.describe()
# Out:
#                  id
# count  39774.000000
# mean   24849.536959
# std    14360.035505
# min        0.000000
# 25%    12398.250000
# 50%    24887.000000
# 75%    37328.500000
# max    49717.000000

# %%
df.rename(columns={'ingredients':'INGREDIENTS'})
# Out:
#           id      cuisine                                        INGREDIENTS
# 0      10259        greek  [romaine lettuce, black olives, grape tomatoes...
# 1      25693  southern_us  [plain flour, ground pepper, salt, tomatoes, g...
# 2      20130     filipino  [eggs, pepper, salt, mayonaise, cooking oil, g...
# 3      22213       indian                [water, vegetable oil, wheat, salt]
# 4      13162       indian  [black pepper, shallots, cornflour, cayenne pe...
# ...      ...          ...                                                ...
# 39769  29109        irish  [light brown sugar, granulated sugar, butter, ...
# 39770  11462      italian  [KRAFT Zesty Italian Dressing, purple onion, b...
# 39771   2238        irish  [eggs, citrus fruit, raisins, sourdough starte...
# 39772  41882      chinese  [boneless chicken skinless thigh, minced garli...
# 39773   2362      mexican  [green chile, jalapeno chilies, onions, ground...
#
# [39774 rows x 3 columns]

# %%
df.columns
# Out:
# Index(['id', 'cuisine', 'ingredients'], dtype='str')

# %%
df['cuisine'].isna()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 39769    False
# 39770    False
# 39771    False
# 39772    False
# 39773    False
# Name: cuisine, Length: 39774, dtype: bool

# %%
df['cuisine'].isna().sum()
# Out:
# np.int64(0)

# %%
df['id'].isna()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 39769    False
# 39770    False
# 39771    False
# 39772    False
# 39773    False
# Name: id, Length: 39774, dtype: bool

# %%
df['id'].isna().sum()
# Out:
# np.int64(0)

# %%
df.index.name = "sr_no"

# %%
df
# Out:
#           id      cuisine                                        ingredients
# sr_no
# 0      10259        greek  [romaine lettuce, black olives, grape tomatoes...
# 1      25693  southern_us  [plain flour, ground pepper, salt, tomatoes, g...
# 2      20130     filipino  [eggs, pepper, salt, mayonaise, cooking oil, g...
# 3      22213       indian                [water, vegetable oil, wheat, salt]
# 4      13162       indian  [black pepper, shallots, cornflour, cayenne pe...
# ...      ...          ...                                                ...
# 39769  29109        irish  [light brown sugar, granulated sugar, butter, ...
# 39770  11462      italian  [KRAFT Zesty Italian Dressing, purple onion, b...
# 39771   2238        irish  [eggs, citrus fruit, raisins, sourdough starte...
# 39772  41882      chinese  [boneless chicken skinless thigh, minced garli...
# 39773   2362      mexican  [green chile, jalapeno chilies, onions, ground...
#
# [39774 rows x 3 columns]

# %%
df.sample(5)
# Out:
#           id     cuisine                                        ingredients
# sr_no
# 37985  49248  vietnamese  [egg roll wrappers, garlic, pork, sesame oil, ...
# 28081  22191  vietnamese  [olive oil, green onions, cucumber, medium shr...
# 27766  41337      indian  [garam masala, garlic, gram flour, water, chil...
# 33943   3509     italian  [dry white wine, salt, black pepper, butter, f...
# 36318  37097  vietnamese  [kosher salt, vegetable oil, roasted peanuts, ...

# %%
df['cuisine']
# Out:
# sr_no
# 0              greek
# 1        southern_us
# 2           filipino
# 3             indian
# 4             indian
#             ...
# 39769          irish
# 39770        italian
# 39771          irish
# 39772        chinese
# 39773        mexican
# Name: cuisine, Length: 39774, dtype: str

# %%
df.drop(['ingredients'],axis=1)
# Out:
#           id      cuisine
# sr_no
# 0      10259        greek
# 1      25693  southern_us
# 2      20130     filipino
# 3      22213       indian
# 4      13162       indian
# ...      ...          ...
# 39769  29109        irish
# 39770  11462      italian
# 39771   2238        irish
# 39772  41882      chinese
# 39773   2362      mexican
#
# [39774 rows x 2 columns]

# %%
df.dropna()
# Out:
#           id      cuisine                                        ingredients
# sr_no
# 0      10259        greek  [romaine lettuce, black olives, grape tomatoes...
# 1      25693  southern_us  [plain flour, ground pepper, salt, tomatoes, g...
# 2      20130     filipino  [eggs, pepper, salt, mayonaise, cooking oil, g...
# 3      22213       indian                [water, vegetable oil, wheat, salt]
# 4      13162       indian  [black pepper, shallots, cornflour, cayenne pe...
# ...      ...          ...                                                ...
# 39769  29109        irish  [light brown sugar, granulated sugar, butter, ...
# 39770  11462      italian  [KRAFT Zesty Italian Dressing, purple onion, b...
# 39771   2238        irish  [eggs, citrus fruit, raisins, sourdough starte...
# 39772  41882      chinese  [boneless chicken skinless thigh, minced garli...
# 39773   2362      mexican  [green chile, jalapeno chilies, onions, ground...
#
# [39774 rows x 3 columns]
