# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import accuracy_score

# %%
df=pd.read_csv('/Users/parikhandelwal/Downloads/archive/patients.csv',encoding='unicode_escape')

# %%
df.head()
# Out:
#      patient_id               name  age arrival_date departure_date  \
# 0  PAT-09484753  Richard Rodriguez   24   2025-03-16     2025-03-22
# 1  PAT-f0644084     Shannon Walker    6   2025-12-13     2025-12-14
# 2  PAT-ac6162e4       Julia Torres   24   2025-06-29     2025-07-05
# 3  PAT-3dda2bb5    Crystal Johnson   32   2025-10-12     2025-10-23
# 4  PAT-08591375        Garrett Lin   25   2025-02-18     2025-02-25
#
#             service  satisfaction
# 0           surgery            61
# 1           surgery            83
# 2  general_medicine            83
# 3         emergency            81
# 4               ICU            76

# %%
df.shape
# Out:
# (1000, 7)

# %%
df.index.name='SR_no'

# %%
df
# Out:
#          patient_id               name  age arrival_date departure_date  \
# SR_no
# 0      PAT-09484753  Richard Rodriguez   24   2025-03-16     2025-03-22
# 1      PAT-f0644084     Shannon Walker    6   2025-12-13     2025-12-14
# 2      PAT-ac6162e4       Julia Torres   24   2025-06-29     2025-07-05
# 3      PAT-3dda2bb5    Crystal Johnson   32   2025-10-12     2025-10-23
# 4      PAT-08591375        Garrett Lin   25   2025-02-18     2025-02-25
# ...             ...                ...  ...          ...            ...
# 995    PAT-a01bf534         Amber Vang   26   2025-12-02     2025-12-04
# 996    PAT-87fa07bd       Martha Smith   89   2025-11-18     2025-11-30
# 997    PAT-8f07e894     Jennifer James   72   2025-12-12     2025-12-21
# 998    PAT-4ae301e1     Kara Hernandez   47   2025-02-08     2025-02-20
# 999    PAT-e2ef9c5f    Lorraine Turner   64   2025-05-04     2025-05-08
#
#                 service  satisfaction
# SR_no
# 0               surgery            61
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   patient_id      1000 non-null   str
#  1   name            1000 non-null   str
#  2   age             1000 non-null   int64
#  3   arrival_date    1000 non-null   str
#  4   departure_date  1000 non-null   str
#  5   service         1000 non-null   str
#  6   satisfaction    1000 non-null   int64
# dtypes: int64(2), str(5)
# memory usage: 54.8 KB

# %%
df.describe()
# Out:
#                age  satisfaction
# count  1000.000000   1000.000000
# mean     45.337000     79.597000
# std      25.999912     11.550325
# min       0.000000     60.000000
# 25%      23.000000     70.000000
# 50%      46.000000     80.000000
# 75%      68.000000     89.250000
# max      89.000000     99.000000

# %%
plt.scatter(df['age'],df['satisfaction'])
plt.xlabel('Age ')
plt.ylabel('satisfaction')
# Out:
# Text(0, 0.5, 'satisfaction')

# %%
X=df.iloc[:,2:3]
Y=df.iloc[:,-1]

# %%
print(X_train)
# Out:
#        age
# SR_no
# 653      0
# 258     81
# 951     73
# 396     58
# 557     27
# ...    ...
# 534     31
# 584     43
# 493     50
# 527     15
# 168     36
#
# [900 rows x 1 columns]

# %%
print(X)
# Out:
#        age
# SR_no
# 0       24
# 1        6
# 2       24
# 3       32
# 4       25
# ...    ...
# 995     26
# 996     89
# 997     72
# 998     47
# 999     64
#
# [1000 rows x 1 columns]

# %%
print(Y)
# Out:
# SR_no
# 0      61
# 1      83
# 2      83
# 3      81
# 4      76
#        ..
# 995    91
# 996    99
# 997    69
# 998    61
# 999    83
# Name: satisfaction, Length: 1000, dtype: int64

# %%
df['service'].value_counts()
# Out:
# service
# emergency           263
# surgery             254
# general_medicine    242
# ICU                 241
# Name: count, dtype: int64

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.1,random_state=2)

# %%
print(X_train)
# Out:
#        age
# SR_no
# 653      0
# 258     81
# 951     73
# 396     58
# 557     27
# ...    ...
# 534     31
# 584     43
# 493     50
# 527     15
# 168     36
#
# [900 rows x 1 columns]

# %%
print(X_test)
# Out:
#        age
# SR_no
# 37      33
# 726     24
# 846      5
# 295     68
# 924     18
# ...    ...
# 158     53
# 715     39
# 881     51
# 824     57
# 518     46
#
# [100 rows x 1 columns]

# %%
print(Y_test)
# Out:
# SR_no
# 37     97
# 726    91
# 846    85
# 295    67
# 924    94
#        ..
# 158    66
# 715    96
# 881    95
# 824    97
# 518    67
# Name: satisfaction, Length: 100, dtype: int64

# %%
lr=LinearRegression()

# %%
lr.fit(X_train,Y_train)#This line trains the Linear Regression model.It tells the model:“Learn relationship between X and y”
# Out:
# LinearRegression()

# %%
print(X_test)
# Out:
#        age
# SR_no
# 37      33
# 726     24
# 846      5
# 295     68
# 924     18
# ...    ...
# 158     53
# 715     39
# 881     51
# 824     57
# 518     46
#
# [100 rows x 1 columns]

# %%
print(Y_test)
# Out:
# SR_no
# 37     97
# 726    91
# 846    85
# 295    67
# 924    94
#        ..
# 158    66
# 715    96
# 881    95
# 824    97
# 518    67
# Name: satisfaction, Length: 100, dtype: int64

# %%
lr.predict(X_test.iloc[0].values.reshape(1,1))
# Out:
# /opt/homebrew/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([79.7705632])

# %%
plt.scatter(df['age'],df['satisfaction'])
plt.plot(X_train,lr.predict(X_train),color='Red')
plt.xlabel('Age ')
plt.ylabel('satisfaction')
# Out:
# Text(0, 0.5, 'satisfaction')

# %%
plt.scatter(df['age'],df['satisfaction'])
plt.plot(X_test,lr.predict(X_test),color='Red')
plt.xlabel('Age ')
plt.ylabel('satisfaction')
# Out:
# Text(0, 0.5, 'satisfaction')

# %%
m = lr.coef_
m
# Out:
# array([-0.02159821])

# %%
b = lr.intercept_
b
# Out:
# np.float64(80.48330413472121)
